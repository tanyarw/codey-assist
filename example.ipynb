# %% [markdown]
# Make sure you've run `gcloud config set project <PROJECT>` in required environments

# %%
# Load the extension

# %load_ext codey_assist

# %%
p = 6

# %%
# %%codey generate
# fibonacci series

# %%
# Generated by codey-assist
def fibonacci(n):
    if n < 2:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)

for i in range(p):
    print(fibonacci(i))

# %%
# %set_index repo-without-index

# %%
# %set_index repo-with-index

# %%
# %%code_qna
# What function is used to extract the template
